# %% [markdown]
# # Практична робота №1
# ### студентки групи МІТ-31
# ### Шмат Катерини Сергіївни

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("./practice1_data.csv")

# %%
df.head()
# Out:
#          x1        x2        x3        x4        x5        x6        x7  \
# 0  2.163950  0.015729 -1.136593  2.182571 -1.552051 -0.909067  1.791084
# 1  1.364464 -1.359741 -1.881798 -0.484231 -1.974301 -0.017010  2.184909
# 2  1.237133  0.945965 -0.008633  0.889645  0.348132 -1.863290 -1.093229
# 3  0.530019  2.739019  1.168152 -0.182967 -0.313546  1.274500  1.097952
# 4 -1.169403 -0.387841  0.049067 -2.136358 -1.839488 -0.635955 -0.136341
#
#          x8        x9       x10  classes
# 0 -1.094894  0.308272 -0.912365        0
# 1 -1.012308 -0.774774 -3.702803        0
# 2  0.057705  1.646754 -0.834884        2
# 3 -0.909685  1.490564  2.300722        1
# 4  0.357952 -0.376029 -2.323494        2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   x1       1500 non-null   float64
#  1   x2       1500 non-null   float64
#  2   x3       1500 non-null   float64
#  3   x4       1500 non-null   float64
#  4   x5       1500 non-null   float64
#  5   x6       1500 non-null   float64
#  6   x7       1500 non-null   float64
#  7   x8       1500 non-null   float64
#  8   x9       1500 non-null   float64
#  9   x10      1500 non-null   float64
#  10  classes  1500 non-null   int64
# dtypes: float64(10), int64(1)
# memory usage: 129.0 KB

# %%
df = df.drop("x1", axis = 1)
df = df.drop("x3", axis = 1)
df = df.drop("x4", axis = 1)
df = df.drop("x7", axis = 1)
df = df.drop("x9", axis = 1)
df = df.drop("x10", axis = 1)
df.head()
# Out:
#          x2        x5        x6        x8  classes
# 0  0.015729 -1.552051 -0.909067 -1.094894        0
# 1 -1.359741 -1.974301 -0.017010 -1.012308        0
# 2  0.945965  0.348132 -1.863290  0.057705        2
# 3  2.739019 -0.313546  1.274500 -0.909685        1
# 4 -0.387841 -1.839488 -0.635955  0.357952        2

# %%
df.describe()
# Out:
#                 x2           x5           x6           x8      classes
# count  1500.000000  1500.000000  1500.000000  1500.000000  1500.000000
# mean     -0.275385    -0.044157     0.042072    -0.244578     1.497333
# std       1.711574     1.003190     1.013082     1.594473     1.117807
# min      -5.631583    -3.620247    -3.667087    -4.642937     0.000000
# 25%      -1.423198    -0.682299    -0.644789    -1.338483     0.000000
# 50%      -0.427568    -0.045481     0.057803    -0.432473     1.000000
# 75%       0.800646     0.660479     0.752421     0.844740     2.000000
# max       5.616177     3.626218     3.363034     6.598312     3.000000

# %%
df["classes"].value_counts()
# Out:
# 0    376
# 2    376
# 1    375
# 3    373
# Name: classes, dtype: int64

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,5), dpi = 100)
fig.suptitle('Distribution of (x2, x5, x6, x8) per classes')


sns.kdeplot(ax = axes[0,0], data = df, x = 'x2', hue = "classes", alpha = 0.5, shade = True)
axes[0,0].set_xlabel("x2")
axes[0,0].get_legend().remove()


sns.kdeplot(ax = axes[0,1], data = df, x = 'x5', hue = "classes", alpha = 0.5, shade = True)
axes[0,1].set_xlabel("x5")
axes[0,1].get_legend().remove()


sns.kdeplot(ax = axes[1,0], data = df, x = 'x6', hue = "classes", alpha = 0.5, shade = True)
axes[1,0].set_xlabel("x6")
axes[1,0].get_legend().remove()


sns.kdeplot(ax = axes[1,1], data = df, x = 'x8', hue = "classes", alpha = 0.5, shade = True)
axes[1,1].set_xlabel("x8")
axes[1,1].get_legend().remove()


plt.tight_layout()

# %%
plt.figure(figsize = (7, 3), dpi = 100)
sns.scatterplot(data = df, x = 'x2', y = 'x5', hue = "classes")
plt.title("Classes clusters based on x2 and x5")
plt.xlabel("x2")
plt.ylabel("x5")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize = (7, 3), dpi = 100)
sns.scatterplot(data = df, x = 'x6', y = 'x8', hue = "classes")
plt.title("Classes clusters based on x6 and x8")
plt.xlabel("x6")
plt.ylabel("x8")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,5), dpi = 100)


sns.boxplot(ax = axes[0,0], data = df, x = "classes", y = 'x2')
axes[0,0].set_xlabel(None)
axes[0,0].set_ylabel(None)
axes[0,0].set_title("Classes with x2")



sns.boxplot(ax = axes[0,1], data = df, x = "classes", y = 'x5')
axes[0,1].set_xlabel(None)
axes[0,1].set_ylabel(None)
axes[0,1].set_title("Classes with x5")


sns.boxplot(ax = axes[1,0], data = df, x = "classes", y = 'x6')
axes[1,0].set_xlabel(None)
axes[1,0].set_ylabel(None)
axes[1,0].set_title("Classes with x6")


sns.boxplot(ax = axes[1,1], data = df, x = "classes", y = 'x8')
axes[1,1].set_xlabel(None)
axes[1,1].set_ylabel(None)
axes[1,1].set_title("Classes with x8")

plt.tight_layout()
plt.subplots_adjust(hspace=0.5)

# %%
plt.figure(figsize = (8, 4), dpi = 100)
sns.heatmap(df.corr(), annot = True, cmap = "viridis", vmin = -1, vmax = 1)
plt.title("Correlation map between variables")
plt.show()

# %%
X = df.drop("classes", axis = 1)
y = df["classes"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() 
Scaled_X_train = scaler.fit_transform(X_train)
Scaled_X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()
log_model.fit(Scaled_X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log_model.predict(Scaled_X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, plot_confusion_matrix, classification_report

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[32,  9, 13, 20],
#        [18, 13, 30, 12],
#        [12, 14, 33,  9],
#        [22,  2, 10, 51]], dtype=int64)

# %%
fig, ax = plt.subplots(dpi = 120)
plot_confusion_matrix(log_model, Scaled_X_test, y_test, ax = ax);

# %%
acc_score = accuracy_score(y_test, y_pred)
round(acc_score, 2)
# Out:
# 0.43

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.38      0.43      0.41        74
#            1       0.34      0.18      0.23        73
#            2       0.38      0.49      0.43        68
#            3       0.55      0.60      0.58        85
#
#     accuracy                           0.43       300
#    macro avg       0.42      0.42      0.41       300
# weighted avg       0.42      0.43      0.42       300
